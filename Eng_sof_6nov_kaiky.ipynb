# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaikysnow/T-cnicasdePrograma-o_UDF/blob/main/Eng_sof_6nov_kaiky.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Operadores

# %%
2**3
# Out:
# 8

# %%
23/7
# Out:
# 3.2857142857142856

# %%
23%7
# Out:
# 2

# %%
5+5*5/5
# Out:
# 10.0

# %%
4**(4/2)+7
# Out:
# 23.0

# %%
'''
Faça um programa que peça dois números a soma.
'''
a = int(input("informe um numero: "))
b = int(input("informe mais um numero: "))
print("O resultado é ", a+b)
# Out:
# informe um numero: 10
# informe mais um numero: 10
# O resultado é  20

# %% [markdown]
# tarefa 2
#
# Faça um programa que leia a nota que um
# aluno tirou em P1(Prova 1) e P2(Prova 2).

# %%
nt1 = float(input("Digite uma nota: "))
nt2 = float(input("Digite mais uma nota: "))

media = (nt1 + nt2) / 2

print(f"Notas digitadas {nt1}, {nt2}, a mediia é {media}")
# Out:
# Digite uma nota: 10
# Digite mais uma nota: 10
# Notas digitadas 10.0, 10.0, a mediia é 15.0

# %% [markdown]
# tarefa 3
#
#
# Leia um nome armazenado em uma variável
# e imprima:

# %%
nome_pessoa = str(input("Digite seu nome: "))

print(f"Ola {nome_pessoa} !")
# Out:
# Digite seu nome: kaiky
# Ola kaiky !

# %% [markdown]
# tarefa 4
#
# Solicite que o usuário digite seu nome.
# Solicite que o usuários digite seu ano de nascimento (formato AAAA)

# %%
nome = str(input("Digite o seu nome: "))

anonsc = int(input("Digite o ano do seu nascimento"))

print(f"{nome}, nasceu em {anonsc}")
# Out:
# Digite o seu nome: kaiky
# Digite o ano do seu nascimento2006
# kaiky, nasceu em 2006

# %% [markdown]
# tarefa 5
#
# Solicite que o usuário digite seu nome e sua idade.

# %%
nome = str(input("Digite o seu nome: "))
ano = int(input("Digite a sua idade: "))

idade = 2025 - ano

print(f"Olá {nome}, você tem {idade} anos")
# Out:
# Digite o seu nome: kaiky
# Digite a sua idade: 2006
# Olá kaiky, você tem 19 anos

# %% [markdown]
# tarefa 6
#
#
# Solicite ao usuário que digite três notas
# depois calcule e exiba a média ponderada.

# %%
n1 = float(input("Digite a primeira nota: "))
n2 = float(input("Digite a segunda nota: "))
n3 = float(input("Digite a terceira nota: "))
media = (n1 * 2 + n2 * 3 + n3 * 5) / 10
print(f"A média ponderada é {media}")

# %% [markdown]
# tarefa 7
#
# 7- Solicite ao usuário três notas e seus
# respectivos pesos, depois calcule e exiba a
# média ponderada.

# %%
n1 = float(input("Digite a primeira nota: "))
n2 = float(input("Digite a segunda nota: "))
n3 = float(input("Digite a terceira nota: "))
peso1 = float(input("Digite o peso da primeira nota: "))
peso2 = float(input("Digite o peso da segunda nota: "))
peso3 = float(input("Digite o peso da terceira nota: "))
media = (n1 * peso1 + n2 * peso2 + n3 * peso3) / (peso1 + peso2 + peso3)
print(f"A média ponderada é {media}")

# %% [markdown]
# tarefa 8
#
# Peça ao usuário um número e exiba a soma
# de seus dígitos.

# %%
numero = int(input("Digite um número: "))
soma = 0
while numero > 0:
    digito = numero % 10
    soma += digito
    numero //= 10
print(f"A soma dos dígitos é {soma}")

# %% [markdown]
# tarefa 9
#
# Peça ao usuário uma palavra e exiba-a
# invertida sem usar laços.

# %%
palavra = str(input("Digite uma palavra: "))
print(palavra[::-1])
